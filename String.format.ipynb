# %%
raggio = 8.4

# %%
area = 3,14 * raggio**2

# %%
circ = 2*3.14*raggio

# %%
s = "L'area è {} mentre la circonferenza èé {}."

# %%
s.format(area,circ)
# Out:
# "L'area è (3, 987.84) mentre la circonferenza é 52.752."
